# %%
spark.sql("select 1").show()
# Out:
# +---+
# |  1|
# +---+
# |  1|
# +---+

# %%
spark.sql("select current_date()").show()
# Out:
# +--------------+
# |current_date()|
# +--------------+
# |    2025-12-15|
# +--------------+
